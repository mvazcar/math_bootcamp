# %% [markdown]
# # Day 4 optimization figures
#
# This notebook regenerates every mathematical plot used in the optimization deck. It uses the same Chad Blue, Chad Green, white-blended contours, gray constraints, and red improvement arrows as the earlier utility notebooks. Outputs are reproducible vector PDF and SVG files.

# %%
# %load_ext autoreload
# %autoreload 2
from regenerate_vector_plots import PLOT_STEMS, make_all

make_all()

# %%
from IPython.display import SVG, display

for stem in PLOT_STEMS:
    display(SVG(filename=f"{stem}.svg"))
