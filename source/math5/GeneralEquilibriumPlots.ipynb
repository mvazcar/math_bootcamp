# %% [markdown]
# # Day 5: General Equilibrium plots
#
# Regenerate the vector PDF and SVG used by the deck with the same palette as the earlier utility and optimization notebooks.

# %%
from regenerate_vector_plots import make_all

make_all()
