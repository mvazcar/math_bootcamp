# %% [markdown]
# # Day 3 vector figures
#
# This notebook regenerates the utility, indifference-curve, and monotonicity figures used in the slides. The canonical palette is Chad Blue `(0.1, 0.1, 0.5)`, Chad Green `(0.0, 0.4, 0.0)`, and the original red improvement arrows. Outputs are reproducible vector PDF and SVG files.

# %%
# %load_ext autoreload
# %autoreload 2
from regenerate_vector_plots import PLOT_STEMS, make_all

make_all()

# %%
from IPython.display import SVG, display

for stem in PLOT_STEMS:
    display(SVG(filename=f"{stem}.svg"))
